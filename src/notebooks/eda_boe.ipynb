# %%
import pandas as pd 
data = pd.read_parquet("C:\\Users\\Jorge\\Desktop\\MASTER_IA\\TFM\\proyecto\\data\\boedataset\\20240610001538_train_calpe.parquet")
data.head(5)
# Out:
#                                                 text  \
# 0                                            # \n\n.
# 1  92 Lunes   II.A. 41371\n\n# II. AUTORIDADES Y ...
# 2  Se promueve a la categoría de magistrada a doñ...
# 3  3. Se promueve a la categoría de magistrada a ...
# 4  Se promueve a la categoría de magistrada a doñ...
#
#                                            file_path            file_name  \
# 0  C:\Users\Jorge\Desktop\MASTER_IA\TFM\proyecto\...  BOE-A-2024-7298.pdf
# 1  C:\Users\Jorge\Desktop\MASTER_IA\TFM\proyecto\...  BOE-A-2024-7298.pdf
# 2  C:\Users\Jorge\Desktop\MASTER_IA\TFM\proyecto\...  BOE-A-2024-7298.pdf
# 3  C:\Users\Jorge\Desktop\MASTER_IA\TFM\proyecto\...  BOE-A-2024-7298.pdf
# 4  C:\Users\Jorge\Desktop\MASTER_IA\TFM\proyecto\...  BOE-A-2024-7298.pdf
#
#          file_type  file_size creation_date last_modified_date  \
# 0  application/pdf     208985    2024-06-09         2024-04-28
# 1  application/pdf     208985    2024-06-09         2024-04-28
# ...

# %%
data.isna().sum()
# Out:
# text                     0
# file_path                0
# file_name                0
# file_type                0
# file_size                0
# creation_date            0
# last_modified_date       0
# fecha_publicacion_boe    0
# orden                    0
# real_decreto             0
# ministerios              0
# pdf_id                   0
# chunk_id                 0
# num_tokens               1
# num_caracteres           1
# label_1_label            1
# label_1_score            1
# label_2_label            1
# label_2_score            1
# label_3_label            1
# label_3_score            1
# dtype: int64
